# %%
import os
import numpy as np
import cv2 
from matplotlib import pyplot as plt
import scipy.io as sio
import sys
import numpy as np
import platform
import statistics


def apply_FAST(source):
    #here fast is only used for detecting the keypoints but later on BRIEF will be used for the 
    img = cv2.imread(source,0)     
    # find the keypoints and descriptors with SIFT
    #kp1, des1 = orb.detectAndCompute(img1,None)
    #kp2, des2 = orb.detectAndCompute(img2,None)   
    
    # Initiate FAST extractor
    #fast = cv2.FastFeatureDetector_create()
    #kp = fast.detect(img,None)
    orb = cv2.xfeatures2d.SIFT_create()
    kp = orb.detect(img, None)
    
    
    # Initiate BRIEF extractor
    #brief = cv2.xfeatures2d.BriefDescriptorExtractor_create()
    #kp1, des1 = brief.compute(img, kp)
    
    kp1, des1 = orb.compute(img, kp)
    
    return kp1, des1




def MATCH_CUSTOM(input1, input2):
    name = input1.split("_")
    number_of_matches = 20;       
    k1, d1 = apply_FAST(input1)
    k2, d2 = apply_FAST(input2)
    
  
    
    #print("Feature Lengths", len(k1), len(k2))
    # create BFMatcher object
    bf = cv2.BFMatcher(cv2.NORM_L2, crossCheck=False)
    # Match descriptors.
    #matches = bf.match(d1,d2)
    matches = bf.knnMatch(d1,d2, k=2)
    # Sort them in the order of their distance.
    #matches = sorted(matches, key = lambda x:x.distance)




    # Apply ratio test
    good = []
    for m,n in matches:
        if m.distance < 0.75 * n.distance:
            good.append([m])
            
            
    
    
   
        
    #print("Good Length: ", len(good))
    print("For entry ", name[0],"between", input1, "and ", input2," Feature Lengths", len(k1), len(k2), "Maches : ", len(good))
    return len(good)
    
    #img1 = cv2.imread(input1,0)
    #img2 = cv2.imread(input2,0)
    #img3 = cv2.drawMatches(img1,k1,img2,k2, matches[:number_of_matches] ,None, flags=2)
    #img3 = cv2.drawMatchesKnn(img1,k1,img2,k2,good,None, flags=2)
    #plt.imshow(img3),plt.show()


#Function to get the list of files in a supplied directory
def files(path):  
    for file in os.listdir(path):
        if os.path.isfile(os.path.join(path, file)):
            yield file



            
            
            
print(sys.version)
platform.python_version()
PWD1 = "017_reference"
entries = list()
file_list = files(PWD1)
for file in file_list:
    if "PNG" in file:
        #print(file)
        entries.append(file)
print(entries)



#Training Stage
match_values = list()
number_of_entries = len(entries)
data = list()
for i in range(0, number_of_entries):
    for j in range(i+1, number_of_entries):
        #print(i, j)
        match_values.append(MATCH_CUSTOM(PWD1 + "\\" + entries[i],PWD1 + "\\" +  entries[j]))
        data.append([i,j,match_values[len(match_values)-1]])
print(match_values)
print(data)

mean_ = int(sum(match_values)/len(match_values))
std_dev = int(statistics.stdev(match_values))

diff = -1;
reference = None
index = -5
mean_new = -5
for x in range(0, len(match_values)):
    if match_values[x] > diff:
        diff = match_values[x]
        reference = entries[data[x][0]]
        index = x       
print(reference)
print("Std dev:" +str(std_dev))
print("Mean" + str(mean_) + "\n \n\n _______________________Training Stage ends here______________________\n\n\n")




#TestingStage
#Confustion_Matrix_base
TP_true_positive  = 0
FN_false_negative = 0
FP_false_positive = 0
TN_true_negative  = 0


PWD2 = "017_questioned"
entries = list()
file_list = files(PWD2)
for file in file_list:
    if "PNG" in file:
        #print(file)
        #actual_class_false +=1
        entries.append(file)
    if "png" in file:
        #print(file)
        #actual_class_true +=1
        entries.append(file)
print(entries)

for x in entries:
    match_count = MATCH_CUSTOM(PWD2 + "\\" + x ,PWD1 + "\\" +  reference)
    if len(x) == 10:
        if abs(match_count-mean_) < std_dev*2:
            TP_true_positive += 1
        else:
            FN_false_negative += 1
    else:
        if abs(match_count-mean_) < std_dev*2:
            FP_false_positive +=1
        else:
            TN_true_negative +=1

print("TP = " + str(TP_true_positive) + " FN = " + str(FN_false_negative) )
print("FP = " + str(FP_false_positive) + " TN = " + str(TN_true_negative) )

accuracy = (TP_true_positive+ TN_true_negative)/24
precision = TP_true_positive/(TP_true_positive+FP_false_positive)
recall = TP_true_positive / (TP_true_positive + FN_false_negative)
f_measure = 2 / (1/precision+1/recall)

print("Accuracy : " + str ( accuracy))   
print("Precision: " + str(precision))
print("Recall   : " + str(recall))
print("F-measure: " + str(f_measure))
# Out:
# 3.5.5 |Anaconda, Inc.| (default, Apr  7 2018, 04:52:34) [MSC v.1900 64 bit (AMD64)]
# ['13_017.PNG', '14_017.PNG', '15_017.PNG', '16_017.PNG', '17_017.PNG', '18_017.PNG', '19_017.PNG', '20_017.PNG', '21_017.PNG', '22_017.PNG', '23_017.PNG', '24_017.PNG']
# For entry  017 between 017_reference\13_017.PNG and  017_reference\14_017.PNG  Feature Lengths 417 392 Maches :  49
# For entry  017 between 017_reference\13_017.PNG and  017_reference\15_017.PNG  Feature Lengths 417 441 Maches :  39
# For entry  017 between 017_reference\13_017.PNG and  017_reference\16_017.PNG  Feature Lengths 417 445 Maches :  37
# For entry  017 between 017_reference\13_017.PNG and  017_reference\17_017.PNG  Feature Lengths 417 451 Maches :  45
# For entry  017 between 017_reference\13_017.PNG and  017_reference\18_017.PNG  Feature Lengths 417 461 Maches :  46
# For entry  017 between 017_reference\13_017.PNG and  017_reference\19_017.PNG  Feature Lengths 417 393 Maches :  54
# For entry  017 between 017_reference\13_017.PNG and  017_reference\20_017.PNG  Feature Lengths 417 387 Maches :  45
# For entry  017 between 017_reference\13_017.PNG and  017_reference\21_017.PNG  Feature Lengths 417 429 Maches :  40
# For entry  017 between 017_reference\13_017.PNG and  017_reference\22_017.PNG  Feature Lengths 417 442 Maches :  46
# For entry  017 between 017_reference\13_017.PNG and  017_reference\23_017.PNG  Feature Lengths 417 411 Maches :  37
# For entry  017 between 017_reference\13_017.PNG and  017_reference\24_017.PNG  Feature Lengths 417 448 Maches :  38
# For entry  017 between 017_reference\14_017.PNG and  017_reference\15_017.PNG  Feature Lengths 392 441 Maches :  59
# For entry  017 between 017_reference\14_017.PNG and  017_reference\16_017.PNG  Feature Lengths 392 445 Maches :  32
# For entry  017 between 017_reference\14_017.PNG and  017_reference\17_017.PNG  Feature Lengths 392 451 Maches :  52
# For entry  017 between 017_reference\14_017.PNG and  017_reference\18_017.PNG  Feature Lengths 392 461 Maches :  42
# For entry  017 between 017_reference\14_017.PNG and  017_reference\19_017.PNG  Feature Lengths 392 393 Maches :  43
# For entry  017 between 017_reference\14_017.PNG and  017_reference\20_017.PNG  Feature Lengths 392 387 Maches :  37
# For entry  017 between 017_reference\14_017.PNG and  017_reference\21_017.PNG  Feature Lengths 392 429 Maches :  34
# For entry  017 between 017_reference\14_017.PNG and  017_reference\22_017.PNG  Feature Lengths 392 442 Maches :  39
# For entry  017 between 017_reference\14_017.PNG and  017_reference\23_017.PNG  Feature Lengths 392 411 Maches :  42
# For entry  017 between 017_reference\14_017.PNG and  017_reference\24_017.PNG  Feature Lengths 392 448 Maches :  36
# For entry  017 between 017_reference\15_017.PNG and  017_reference\16_017.PNG  Feature Lengths 441 445 Maches :  53
# For entry  017 between 017_reference\15_017.PNG and  017_reference\17_017.PNG  Feature Lengths 441 451 Maches :  69
# For entry  017 between 017_reference\15_017.PNG and  017_reference\18_017.PNG  Feature Lengths 441 461 Maches :  52
# For entry  017 between 017_reference\15_017.PNG and  017_reference\19_017.PNG  Feature Lengths 441 393 Maches :  74
# For entry  017 between 017_reference\15_017.PNG and  017_reference\20_017.PNG  Feature Lengths 441 387 Maches :  56
# For entry  017 between 017_reference\15_017.PNG and  017_reference\21_017.PNG  Feature Lengths 441 429 Maches :  72
# For entry  017 between 017_reference\15_017.PNG and  017_reference\22_017.PNG  Feature Lengths 441 442 Maches :  55
# For entry  017 between 017_reference\15_017.PNG and  017_reference\23_017.PNG  Feature Lengths 441 411 Maches :  67
# For entry  017 between 017_reference\15_017.PNG and  017_reference\24_017.PNG  Feature Lengths 441 448 Maches :  62
# For entry  017 between 017_reference\16_017.PNG and  017_reference\17_017.PNG  Feature Lengths 445 451 Maches :  75
# For entry  017 between 017_reference\16_017.PNG and  017_reference\18_017.PNG  Feature Lengths 445 461 Maches :  45
# For entry  017 between 017_reference\16_017.PNG and  017_reference\19_017.PNG  Feature Lengths 445 393 Maches :  61
# For entry  017 between 017_reference\16_017.PNG and  017_reference\20_017.PNG  Feature Lengths 445 387 Maches :  52
# For entry  017 between 017_reference\16_017.PNG and  017_reference\21_017.PNG  Feature Lengths 445 429 Maches :  52
# For entry  017 between 017_reference\16_017.PNG and  017_reference\22_017.PNG  Feature Lengths 445 442 Maches :  63
# For entry  017 between 017_reference\16_017.PNG and  017_reference\23_017.PNG  Feature Lengths 445 411 Maches :  66
# For entry  017 between 017_reference\16_017.PNG and  017_reference\24_017.PNG  Feature Lengths 445 448 Maches :  51
# For entry  017 between 017_reference\17_017.PNG and  017_reference\18_017.PNG  Feature Lengths 451 461 Maches :  64
# For entry  017 between 017_reference\17_017.PNG and  017_reference\19_017.PNG  Feature Lengths 451 393 Maches :  54
# For entry  017 between 017_reference\17_017.PNG and  017_reference\20_017.PNG  Feature Lengths 451 387 Maches :  51
# For entry  017 between 017_reference\17_017.PNG and  017_reference\21_017.PNG  Feature Lengths 451 429 Maches :  79
# For entry  017 between 017_reference\17_017.PNG and  017_reference\22_017.PNG  Feature Lengths 451 442 Maches :  62
# For entry  017 between 017_reference\17_017.PNG and  017_reference\23_017.PNG  Feature Lengths 451 411 Maches :  56
# For entry  017 between 017_reference\17_017.PNG and  017_reference\24_017.PNG  Feature Lengths 451 448 Maches :  78
# For entry  017 between 017_reference\18_017.PNG and  017_reference\19_017.PNG  Feature Lengths 461 393 Maches :  56
# For entry  017 between 017_reference\18_017.PNG and  017_reference\20_017.PNG  Feature Lengths 461 387 Maches :  47
# For entry  017 between 017_reference\18_017.PNG and  017_reference\21_017.PNG  Feature Lengths 461 429 Maches :  47
# For entry  017 between 017_reference\18_017.PNG and  017_reference\22_017.PNG  Feature Lengths 461 442 Maches :  58
# For entry  017 between 017_reference\18_017.PNG and  017_reference\23_017.PNG  Feature Lengths 461 411 Maches :  62
# For entry  017 between 017_reference\18_017.PNG and  017_reference\24_017.PNG  Feature Lengths 461 448 Maches :  60
# For entry  017 between 017_reference\19_017.PNG and  017_reference\20_017.PNG  Feature Lengths 393 387 Maches :  54
# For entry  017 between 017_reference\19_017.PNG and  017_reference\21_017.PNG  Feature Lengths 393 429 Maches :  62
# For entry  017 between 017_reference\19_017.PNG and  017_reference\22_017.PNG  Feature Lengths 393 442 Maches :  63
# For entry  017 between 017_reference\19_017.PNG and  017_reference\23_017.PNG  Feature Lengths 393 411 Maches :  48
# For entry  017 between 017_reference\19_017.PNG and  017_reference\24_017.PNG  Feature Lengths 393 448 Maches :  57
# For entry  017 between 017_reference\20_017.PNG and  017_reference\21_017.PNG  Feature Lengths 387 429 Maches :  43
# For entry  017 between 017_reference\20_017.PNG and  017_reference\22_017.PNG  Feature Lengths 387 442 Maches :  42
# For entry  017 between 017_reference\20_017.PNG and  017_reference\23_017.PNG  Feature Lengths 387 411 Maches :  52
# For entry  017 between 017_reference\20_017.PNG and  017_reference\24_017.PNG  Feature Lengths 387 448 Maches :  56
# For entry  017 between 017_reference\21_017.PNG and  017_reference\22_017.PNG  Feature Lengths 429 442 Maches :  49
# For entry  017 between 017_reference\21_017.PNG and  017_reference\23_017.PNG  Feature Lengths 429 411 Maches :  45
# For entry  017 between 017_reference\21_017.PNG and  017_reference\24_017.PNG  Feature Lengths 429 448 Maches :  50
# For entry  017 between 017_reference\22_017.PNG and  017_reference\23_017.PNG  Feature Lengths 442 411 Maches :  43
# For entry  017 between 017_reference\22_017.PNG and  017_reference\24_017.PNG  Feature Lengths 442 448 Maches :  48
# For entry  017 between 017_reference\23_017.PNG and  017_reference\24_017.PNG  Feature Lengths 411 448 Maches :  48
# [49, 39, 37, 45, 46, 54, 45, 40, 46, 37, 38, 59, 32, 52, 42, 43, 37, 34, 39, 42, 36, 53, 69, 52, 74, 56, 72, 55, 67, 62, 75, 45, 61, 52, 52, 63, 66, 51, 64, 54, 51, 79, 62, 56, 78, 56, 47, 47, 58, 62, 60, 54, 62, 63, 48, 57, 43, 42, 52, 56, 49, 45, 50, 43, 48, 48]
# [[0, 1, 49], [0, 2, 39], [0, 3, 37], [0, 4, 45], [0, 5, 46], [0, 6, 54], [0, 7, 45], [0, 8, 40], [0, 9, 46], [0, 10, 37], [0, 11, 38], [1, 2, 59], [1, 3, 32], [1, 4, 52], [1, 5, 42], [1, 6, 43], [1, 7, 37], [1, 8, 34], [1, 9, 39], [1, 10, 42], [1, 11, 36], [2, 3, 53], [2, 4, 69], [2, 5, 52], [2, 6, 74], [2, 7, 56], [2, 8, 72], [2, 9, 55], [2, 10, 67], [2, 11, 62], [3, 4, 75], [3, 5, 45], [3, 6, 61], [3, 7, 52], [3, 8, 52], [3, 9, 63], [3, 10, 66], [3, 11, 51], [4, 5, 64], [4, 6, 54], [4, 7, 51], [4, 8, 79], [4, 9, 62], [4, 10, 56], [4, 11, 78], [5, 6, 56], [5, 7, 47], [5, 8, 47], [5, 9, 58], [5, 10, 62], [5, 11, 60], [6, 7, 54], [6, 8, 62], [6, 9, 63], [6, 10, 48], [6, 11, 57], [7, 8, 43], [7, 9, 42], [7, 10, 52], [7, 11, 56], [8, 9, 49], [8, 10, 45], [8, 11, 50], [9, 10, 43], [9, 11, 48], [10, 11, 48]]
# 17_017.PNG
# Std dev:11
# Mean52
#
#
#  _______________________Training Stage ends here______________________
#
#
#
# ['01_0107017.PNG', '01_0124017.PNG', '01_017.png', '01_0211017.PNG', '02_0107017.PNG', '02_0124017.PNG', '02_017.png', '02_0211017.PNG', '03_0107017.PNG', '03_0124017.PNG', '03_017.png', '03_0211017.PNG', '04_0107017.PNG', '04_0124017.PNG', '04_017.png', '04_0211017.PNG', '05_017.png', '06_017.png', '07_017.png', '08_017.png', '09_017.png', '10_017.png', '11_017.png', '12_017.png']
# For entry  017 between 017_questioned\01_0107017.PNG and  017_reference\17_017.PNG  Feature Lengths 532 451 Maches :  32
# For entry  017 between 017_questioned\01_0124017.PNG and  017_reference\17_017.PNG  Feature Lengths 494 451 Maches :  58
# For entry  017 between 017_questioned\01_017.png and  017_reference\17_017.PNG  Feature Lengths 447 451 Maches :  54
# For entry  017 between 017_questioned\01_0211017.PNG and  017_reference\17_017.PNG  Feature Lengths 409 451 Maches :  42
# For entry  017 between 017_questioned\02_0107017.PNG and  017_reference\17_017.PNG  Feature Lengths 517 451 Maches :  41
# For entry  017 between 017_questioned\02_0124017.PNG and  017_reference\17_017.PNG  Feature Lengths 584 451 Maches :  54
# For entry  017 between 017_questioned\02_017.png and  017_reference\17_017.PNG  Feature Lengths 416 451 Maches :  57
# For entry  017 between 017_questioned\02_0211017.PNG and  017_reference\17_017.PNG  Feature Lengths 382 451 Maches :  47
# For entry  017 between 017_questioned\03_0107017.PNG and  017_reference\17_017.PNG  Feature Lengths 442 451 Maches :  42
# For entry  017 between 017_questioned\03_0124017.PNG and  017_reference\17_017.PNG  Feature Lengths 620 451 Maches :  60
# For entry  017 between 017_questioned\03_017.png and  017_reference\17_017.PNG  Feature Lengths 428 451 Maches :  44
# For entry  017 between 017_questioned\03_0211017.PNG and  017_reference\17_017.PNG  Feature Lengths 431 451 Maches :  48
# For entry  017 between 017_questioned\04_0107017.PNG and  017_reference\17_017.PNG  Feature Lengths 532 451 Maches :  50
# For entry  017 between 017_questioned\04_0124017.PNG and  017_reference\17_017.PNG  Feature Lengths 607 451 Maches :  51
# For entry  017 between 017_questioned\04_017.png and  017_reference\17_017.PNG  Feature Lengths 418 451 Maches :  53
# For entry  017 between 017_questioned\04_0211017.PNG and  017_reference\17_017.PNG  Feature Lengths 380 451 Maches :  32
# For entry  017 between 017_questioned\05_017.png and  017_reference\17_017.PNG  Feature Lengths 418 451 Maches :  47
# For entry  017 between 017_questioned\06_017.png and  017_reference\17_017.PNG  Feature Lengths 446 451 Maches :  65
# For entry  017 between 017_questioned\07_017.png and  017_reference\17_017.PNG  Feature Lengths 443 451 Maches :  56
# For entry  017 between 017_questioned\08_017.png and  017_reference\17_017.PNG  Feature Lengths 428 451 Maches :  56
# For entry  017 between 017_questioned\09_017.png and  017_reference\17_017.PNG  Feature Lengths 444 451 Maches :  59
# For entry  017 between 017_questioned\10_017.png and  017_reference\17_017.PNG  Feature Lengths 393 451 Maches :  46
# For entry  017 between 017_questioned\11_017.png and  017_reference\17_017.PNG  Feature Lengths 372 451 Maches :  44
# For entry  017 between 017_questioned\12_017.png and  017_reference\17_017.PNG  Feature Lengths 490 451 Maches :  78
# TP = 11 FN = 1
# FP = 12 TN = 0
# Accuracy : 0.4583333333333333
# Precision: 0.4782608695652174
# Recall   : 0.9166666666666666
# F-measure: 0.6285714285714286
